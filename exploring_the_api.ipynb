# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://monitoring.bbc.co.uk/api/v0/login"

headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json',
}

json_data = {
    'username': 'joseph.shingleton@glasgow.ac.uk',
    'password': ';=.8-NkWuHxCdev',
}

s = requests.session()
response = s.post('https://monitoring.bbc.co.uk/api/v0/login', headers=headers, json=json_data)
response
# Out:
# <Response [204]>

# %%
result = s.get('https://monitoring.bbc.co.uk/api/v0/search?headline=Mogadishu&limit=20&sort=publication_time&sortDirection=DESC')

# %%
result.json()
# Out:
# {'products': [{'id': 'c204xcqt',
#    'headline': 'Somali president, CIA director hold talks in Mogadishu',
#    'publicationTime': '2024-01-18T13:46:04.846Z',
#    'broadcastTime': '2024-01-18T00:01:00Z',
#    'category': 'NEWS_ALERT',
#    'group': 'NEWS_ALERT',
#    'sourceId': 'SONNAW',
#    'sourceType': 'AG',
#    'sourceCity': 'Mogadishu',
#    'languageName': 'Somali',
#    'subjectCountryIds': ['SOM', 'USA', 'KEN'],
#    'topics': ['INTERNATIONAL POLITICAL', 'MILITARY'],
#    'keyRole': None},
#   {'id': 'c204x4w3',
#    'headline': 'al-Shabab puts Mogadishu hotel bombing death toll at 17',
#    'publicationTime': '2024-01-16T18:22:34.694Z',
#    'broadcastTime': '2024-01-16T00:01:00Z',
#    'category': 'NEWS_ALERT',
#    'group': 'NEWS_ALERT',
#    'sourceId': 'CALAMW',
#    'sourceType': 'ON',
#    'sourceCity': None,
#    'languageName': 'Somali',
#    'subjectCountryIds': ['SOM'],
#    'topics': ['TERRORISM', 'DOMESTIC POLITICAL'],
#    'keyRole': None},
# ...

# %%
article = s.get('https://monitoring.bbc.co.uk/api/v0/product/c204xcqt')

# %%
article.json()
# Out:
# {'id': 'c204xcqt',
#  'headline': 'Somali president, CIA director hold talks in Mogadishu',
#  'publicationTime': '2024-01-18T13:46:04.846Z',
#  'broadcastTime': '2024-01-18T00:01:00Z',
#  'category': 'NEWS_ALERT',
#  'group': 'NEWS_ALERT',
#  'sourceId': 'SONNAW',
#  'sourceType': 'AG',
#  'sourceCity': 'Mogadishu',
#  'languageName': 'Somali',
#  'subjectCountryIds': ['SOM', 'USA', 'KEN'],
#  'topics': ['INTERNATIONAL POLITICAL', 'MILITARY'],
# ...

# %%
soup = BeautifulSoup(article.json()['bodyHtml'], features="html.parser")
text = soup.get_text()
lines = (line.strip() for line in text.splitlines())
chunks = (phrase.strip() for line in lines for phrase in line.split(" "))
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# By
# BBC
# Monitoring
# Somalia’s
# President
# Hassan
# Sheikh
# Mohamud
# held
# a
# meeting
# with
# visiting
# CIA
# Director
# William
# Burns
# in
# the
# capital,
# Mogadishu,
# state-owned
# Somali
# National
# News
# Agency
# (Sonna)
# reported
# on
# 18
# January.
# "Mr
# Hassan
# Sheikh
# Mohamud,
# the
# Somali
# president,
# and
# William
# Burns
# discussed
# regional
# issues,
# bilateral
# interests
# and
# strengthening
# the
# strategic
# collaboration
# such
# as
# the
# war
# against
# international
# terrorism
# as
# well
# as
# improving
# peace
# and
# stability
# in
# the
# region,"
# the
# website
# said.
# Burns
# visited
# Mogadishu
# days
# after
# he
# toured
# Kenya
# and
# met
# President
# William
# Samoei
# Ruto.
# The
# US
# supports
# Somalia
# and
# has
# tens
# of
# soldiers
# based
# at
# an
# airfield
# near
# southern
# Wanlaweyne
# town,
# located
# some
# 90km
# northwest
# of
# Mogadishu.
# The
# troops
# usually
# conduct
# aerial
# ...

# %%
# getting a list of valid regions
